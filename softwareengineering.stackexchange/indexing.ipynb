# %%
# !pip install ipython-sql
# !pip install pgspecial
# Out:
# ...
# /usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.23ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# ...
#   Using cached pgspecial-1.13.1-py3-none-any.whl (35 kB)
# ...
#   Using cached psycopg2-2.9.3.tar.gz (380 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-czjsa6rh/psycopg2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-czjsa6rh/psycopg2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-5jc0qeua
# ...

# %%
# %load_ext sql

# %%
# %sql postgresql://sanil:root@localhost/raspberrypidata

# %% [markdown]
# # Indexing

# %%
# %%sql
# SELECT * FROM posts WHERE owner_display_name='user8';
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 780 rows affected.
# [(1022650, 2, 0, '2010-09-11T23:13:40.893', 11, 0, 'No body', 'user8', -1, '2020-06-16T10:01:49.770', '2010-09-11T23:13:40.893', None, None, None, 2, None, 'CC BY-SA 2.5', 0, None, 2932.0, None, None),
#  (1022663, 5, 0, '2010-09-12T06:08:18.800', 0, 0, 'No body', 'user8', 76422, '2016-09-20T11:14:46.877', '2016-09-20T11:14:46.877', None, None, None, 0, None, 'CC BY-SA 3.0', 0, None, None, None, '2014-01-23T04:36:43.397'),
#  (1022664, 4, 0, '2010-09-12T06:08:18.800', 0, 0, 'No body', 'user8', 44, '2011-04-10T03:00:34.627', '2011-04-10T03:00:34.627', None, None, None, 0, None, 'CC BY-SA 3.0', 0, None, None, None, None),
#  (1022774, 2, 0, '2010-09-13T16:35:48.913', 60, 0, 'No body', 'user8', 0, '2010-09-13T20:22:42.963', '2010-09-13T20:22:42.963', None, None, None, 9, None, 'CC BY-SA 2.5', 0, None, 3272.0, 'user8', None),
# ...

# %%
# %%sql
# EXPLAIN ANALYZE SELECT * FROM posts WHERE owner_display_name='user8';
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 8 rows affected.
# [('Gather  (cost=1000.00..75228.38 rows=763 width=306) (actual time=0.267..142.818 rows=780 loops=1)',),
#  ('  Workers Planned: 2',),
#  ('  Workers Launched: 2',),
#  ('  ->  Parallel Seq Scan on posts  (cost=0.00..74152.08 rows=318 width=306) (actual time=0.051..117.567 rows=260 loops=3)',),
#  ("        Filter: ((owner_display_name)::text = 'user8'::text)",),
#  ('        Rows Removed by Filter: 763917',),
#  ('Planning Time: 0.108 ms',),
#  ('Execution Time: 142.901 ms',)]

# %%
# %%sql
# CREATE INDEX posts_owner_display_name_idx ON posts (owner_display_name);
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# Done.
# []

# %%
# %%sql
# EXPLAIN ANALYZE SELECT * FROM posts WHERE owner_display_name='user8';
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 4 rows affected.
# [('Index Scan using test1_id_index on posts  (cost=0.43..691.91 rows=764 width=306) (actual time=0.037..2.785 rows=780 loops=1)',),
#  ("  Index Cond: ((owner_display_name)::text = 'user8'::text)",),
#  ('Planning Time: 0.201 ms',),
#  ('Execution Time: 2.839 ms',)]
