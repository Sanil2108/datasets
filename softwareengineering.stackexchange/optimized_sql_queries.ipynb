# %%
# !pip install ipython-sql
# !pip install pgspecial
# Out:
# Requirement already satisfied: ipython-sql in /home/sanil/.local/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: prettytable<1 in /home/sanil/.local/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython>=1.0 in /home/sanil/.local/lib/python3.8/site-packages (from ipython-sql) (7.30.1)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /home/sanil/.local/lib/python3.8/site-packages (from ipython-sql) (1.4.29)
# Requirement already satisfied: sqlparse in /home/sanil/.local/lib/python3.8/site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from ipython-sql) (1.14.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/lib/python3/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython>=1.0->ipython-sql) (60.9.3)
# Requirement already satisfied: jedi>=0.16 in /home/sanil/.local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: decorator in /usr/lib/python3/dist-packages (from ipython>=1.0->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/lib/python3/dist-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /home/sanil/.local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/lib/python3/dist-packages (from ipython>=1.0->ipython-sql) (2.0.10)
# Requirement already satisfied: pygments in /usr/lib/python3/dist-packages (from ipython>=1.0->ipython-sql) (2.3.1)
# Requirement already satisfied: backcall in /usr/lib/python3/dist-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: matplotlib-inline in /home/sanil/.local/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.3)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from ipython>=1.0->ipython-sql) (4.6.0)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /home/sanil/.local/lib/python3.8/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/sanil/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# /usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.23ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/pkg_resources/__init__.py:122: PkgResourcesDeprecationWarning: 0.1.36ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# Collecting pgspecial
#   Using cached pgspecial-1.13.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: click>=4.1 in /home/sanil/.local/lib/python3.8/site-packages (from pgspecial) (7.1.2)
# Requirement already satisfied: sqlparse>=0.1.19 in /home/sanil/.local/lib/python3.8/site-packages (from pgspecial) (0.4.2)
# Collecting psycopg2>=2.7.4
#   Using cached psycopg2-2.9.3.tar.gz (380 kB)
# Building wheels for collected packages: psycopg2
#   Building wheel for psycopg2 (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-a4i_povk/psycopg2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-a4i_povk/psycopg2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-y0gs2qb2
#        cwd: /tmp/pip-install-a4i_povk/psycopg2/
#   Complete output (38 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.8
#   creating build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/sql.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/_range.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/errorcodes.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/_ipaddress.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/tz.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/__init__.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/_json.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/extensions.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/pool.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/errors.py -> build/lib.linux-x86_64-3.8/psycopg2
#   copying lib/extras.py -> build/lib.linux-x86_64-3.8/psycopg2
#   running build_ext
#   building 'psycopg2._psycopg' extension
#   creating build/temp.linux-x86_64-3.8
#   creating build/temp.linux-x86_64-3.8/psycopg
#   x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC "-DPSYCOPG_VERSION=2.9.3 (dt dec pq3 ext lo64)" -DPSYCOPG_DEBUG=1 -DPG_VERSION_NUM=120009 -DHAVE_LO64=1 -DPSYCOPG_DEBUG=1 -I/usr/include/python3.8 -I. -I/usr/include/postgresql -I/usr/include/postgresql/12/server -I/usr/include/libxml2 -I/usr/include/mit-krb5 -c psycopg/adapter_asis.c -o build/temp.linux-x86_64-3.8/psycopg/adapter_asis.o -Wdeclaration-after-statement
#   In file included from psycopg/adapter_asis.c:28:
#   ./psycopg/psycopg.h:36:10: fatal error: libpq-fe.h: No such file or directory
#      36 | #include <libpq-fe.h>
#         |          ^~~~~~~~~~~~
#   compilation terminated.
#
#   It appears you are missing some prerequisite to build the package from source.
#
#   You may install a binary package by installing 'psycopg2-binary' from PyPI.
#   If you want to install psycopg2 from source, please install the packages
#   required for the build and try again.
#
#   For further information please check the 'doc/src/install.rst' file (also at
#   <https://www.psycopg.org/docs/install.html>).
#
#   error: command '/usr/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for psycopg2
#   Running setup.py clean for psycopg2
# Failed to build psycopg2
# Installing collected packages: psycopg2, pgspecial
#     Running setup.py install for psycopg2 ... error
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-a4i_povk/psycopg2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-a4i_povk/psycopg2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-ynmtl820/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/sanil/.local/include/python3.8/psycopg2
#          cwd: /tmp/pip-install-a4i_povk/psycopg2/
#     Complete output (40 lines):
#     running install
#     /usr/local/lib/python3.8/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.8
#     creating build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/sql.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/_range.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/errorcodes.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/_ipaddress.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/tz.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/__init__.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/_json.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/extensions.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/pool.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/errors.py -> build/lib.linux-x86_64-3.8/psycopg2
#     copying lib/extras.py -> build/lib.linux-x86_64-3.8/psycopg2
#     running build_ext
#     building 'psycopg2._psycopg' extension
#     creating build/temp.linux-x86_64-3.8
#     creating build/temp.linux-x86_64-3.8/psycopg
#     x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC "-DPSYCOPG_VERSION=2.9.3 (dt dec pq3 ext lo64)" -DPSYCOPG_DEBUG=1 -DPG_VERSION_NUM=120009 -DHAVE_LO64=1 -DPSYCOPG_DEBUG=1 -I/usr/include/python3.8 -I. -I/usr/include/postgresql -I/usr/include/postgresql/12/server -I/usr/include/libxml2 -I/usr/include/mit-krb5 -c psycopg/adapter_asis.c -o build/temp.linux-x86_64-3.8/psycopg/adapter_asis.o -Wdeclaration-after-statement
#     In file included from psycopg/adapter_asis.c:28:
#     ./psycopg/psycopg.h:36:10: fatal error: libpq-fe.h: No such file or directory
#        36 | #include <libpq-fe.h>
#           |          ^~~~~~~~~~~~
#     compilation terminated.
#
#     It appears you are missing some prerequisite to build the package from source.
#
#     You may install a binary package by installing 'psycopg2-binary' from PyPI.
#     If you want to install psycopg2 from source, please install the packages
#     required for the build and try again.
#
#     For further information please check the 'doc/src/install.rst' file (also at
#     <https://www.psycopg.org/docs/install.html>).
#
#     error: command '/usr/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-a4i_povk/psycopg2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-a4i_povk/psycopg2/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-ynmtl820/install-record.txt --single-version-externally-managed --user --prefix= --compile --install-headers /home/sanil/.local/include/python3.8/psycopg2 Check the logs for full command output.

# %%
# %load_ext sql

# %%
# %sql postgresql://sanil:root@localhost/raspberrypidata

# %% [markdown]
# # Optimised SQL Queries

# %%
# %%sql
# SELECT COUNT(*) FROM posts;
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 1 rows affected.
# [(2292531,)]

# %%
# %%sql
# SELECT * FROM posts ORDER BY post_id LIMIT 10 OFFSET 10;
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 10 rows affected.
# [(1021684, 2, 0, '2010-09-01T19:49:46.223', 11, 0, 'No body', 'No Owner', 11, '2010-09-01T20:07:09.027', '2010-09-01T20:07:09.027', None, None, None, 4, None, 'CC BY-SA 2.5', 11, None, 9.0, None, '2011-01-04T21:22:43.957'),
#  (1021685, 2, 0, '2010-09-01T19:50:32.013', 6, 0, 'No body', 'No Owner', 0, None, '2010-09-01T19:50:32.013', None, None, None, 0, None, 'CC BY-SA 2.5', 21, None, 18.0, None, None),
#  (1021686, 2, 0, '2010-09-01T19:50:53.817', 34, 0, 'No body', 'No Owner', 0, None, '2010-09-01T19:50:53.817', None, None, None, 1, None, 'CC BY-SA 2.5', 17, None, 4.0, None, None),
#  (1021687, 1, 54, '2010-09-01T19:57:03.197', 9, 601, 'No body', 'No Owner', 0, None, '2012-05-30T05:28:11.037', 'How much effort should be put in each part of a waterfall project?', '<project-management><waterfall>', 2.0, 0, 0.0, 'CC BY-SA 2.5', 9, None, None, None, None),
#  (1021688, 2, 0, '2010-09-01T19:57:48.190', 7, 0, 'No body', 'No Owner', 38, '2010-09-01T22:32:06.070', '2010-09-01T22:32:06.070', None, None, None, 0, None, 'CC BY-SA 2.5', 38, None, 9.0, None, '2011-01-04T21:22:43.957'),
#  (1021689, 1, 110, '2010-09-01T19:58:10.203', 23, 1899, 'No body', 'No Owner', 31260, '2016-03-23T10:24:13.970', '2016-03-23T10:24:13.970', 'How do I cope with a manager who’s always interfering in what I do, but doesn’t really understand it?', '<communication>', 8.0, 4, 3.0, 'CC BY-SA 2.5', 47, None, None, None, None),
#  (1021690, 1, 0, '2010-09-01T19:58:47.137', 71, 145399, 'No body', 'No Owner', 4, '2016-01-08T13:13:18.957', '2016-01-08T13:13:18.957', 'Are certifications worth it?', '<skills>', 29.0, 10, 72.0, 'CC BY-SA 3.0', 41, None, None, 'user8', '2011-09-08T18:49:58.933'),
#  (1021691, 2, 0, '2010-09-01T20:01:18.783', 2, 0, 'No body', 'No Owner', 0, None, '2010-09-01T20:01:18.783', None, None, None, 0, None, 'CC BY-SA 2.5', 12, None, 9.0, None, '2011-01-04T21:22:43.957'),
#  (1021692, 2, 0, '2010-09-01T20:02:42.657', 1, 0, 'No body', 'No Owner', 0, None, '2010-09-01T20:02:42.657', None, None, None, 0, None, 'CC BY-SA 2.5', 38, None, 39.0, None, '2010-09-04T10:57:01.747'),
#  (1021693, 2, 0, '2010-09-01T20:03:09.650', 39, 0, 'No body', 'No Owner', 666, '2010-09-27T15:19:26.050', '2010-09-27T15:19:26.050', None, None, None, 5, None, 'CC BY-SA 2.5', 41, None, 39.0, None, '2010-09-04T10:57:01.747')]

# %%
# %%sql
# SELECT * FROM posts ORDER BY post_id LIMIT 10 OFFSET 100000;
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 10 rows affected.
# [(1121674, 2, 0, '2013-05-01T15:36:35.997', 1, 0, 'No body', 'No Owner', 0, None, '2013-05-01T15:36:35.997', None, None, None, 0, None, 'CC BY-SA 3.0', 24696, None, 196731.0, None, None),
#  (1121675, 2, 0, '2013-05-01T15:38:03.977', 0, 0, 'No body', 'No Owner', 0, None, '2013-05-01T15:38:03.977', None, None, None, 0, None, 'CC BY-SA 3.0', 10563, None, 196738.0, None, None),
#  (1121676, 2, 0, '2013-05-01T15:39:09.263', 4, 0, 'No body', 'No Owner', 935, '2013-05-01T15:45:51.203', '2013-05-01T15:45:51.203', None, None, None, 1, None, 'CC BY-SA 3.0', 935, None, 196738.0, None, None),
#  (1121677, 2, 0, '2013-05-01T15:56:20.027', 1, 0, 'No body', 'No Owner', 0, None, '2013-05-01T15:56:20.027', None, None, None, 0, None, 'CC BY-SA 3.0', 89193, None, 183645.0, None, None),
#  (1121678, 2, 0, '2013-05-01T16:05:50.613', 0, 0, 'No body', 'No Owner', 0, None, '2013-05-01T16:05:50.613', None, None, None, 0, None, 'CC BY-SA 3.0', 89193, None, 196586.0, None, None),
#  (1121679, 2, 0, '2013-05-01T16:36:24.330', 2, 0, 'No body', 'No Owner', 0, None, '2013-05-01T16:36:24.330', None, None, None, 4, None, 'CC BY-SA 3.0', 89784, None, 196709.0, None, None),
#  (1121680, 1, 196753, '2013-05-01T16:59:52.683', 1, 620, 'No body', 'No Owner', 60327, '2013-05-01T17:43:21.023', '2013-05-01T17:57:13.393', 'Pairwise testing, not possible to say which combinations is faulty?', '<testing><math><theory>', 1.0, 0, 1.0, 'CC BY-SA 3.0', 60327, None, None, None, None),
#  (1121681, 2, 0, '2013-05-01T17:40:03.957', 2, 0, 'No body', 'user53019', 0, '2013-05-01T17:57:13.393', '2013-05-01T17:57:13.393', None, None, None, 4, None, 'CC BY-SA 3.0', 0, None, 196750.0, 'user53019', None),
#  (1121682, 2, 0, '2013-05-01T17:53:07.447', 4, 0, 'No body', 'No Owner', 89813, '2013-05-02T10:33:02.163', '2013-05-02T10:33:02.163', None, None, None, 0, None, 'CC BY-SA 3.0', 89813, None, 189354.0, None, None),
#  (1121683, 2, 0, '2013-05-01T18:53:18.960', 5, 0, 'No body', 'No Owner', 0, None, '2013-05-01T18:53:18.960', None, None, None, 0, None, 'CC BY-SA 3.0', 6431, None, 196757.0, None, None)]

# %%
# %%sql
# EXPLAIN ANALYZE SELECT * FROM posts ORDER BY post_id LIMIT 10 OFFSET 100000;
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 4 rows affected.
# [('Limit  (cost=5806.04..5806.63 rows=10 width=306) (actual time=16.953..16.955 rows=10 loops=1)',),
#  ('  ->  Index Scan using posts_pkey on posts  (cost=0.43..132926.65 rows=2289615 width=306) (actual time=0.028..14.529 rows=100010 loops=1)',),
#  ('Planning Time: 0.135 ms',),
#  ('Execution Time: 16.983 ms',)]

# %%
# %%sql
# SELECT
#    column_name,
#    data_type
# FROM
#    information_schema.columns
# WHERE
#    table_name = 'posts';
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 22 rows affected.
# [('post_id', 'integer'),
#  ('post_type_id', 'integer'),
#  ('accepted_answer_id', 'integer'),
#  ('creation_date', 'character varying'),
#  ('score', 'integer'),
#  ('view_count', 'integer'),
#  ('body', 'character varying'),
#  ('owner_display_name', 'character varying'),
#  ('last_editor_user_id', 'integer'),
#  ('last_edit_date', 'character varying'),
#  ('last_activity_date', 'character varying'),
#  ('title', 'character varying'),
#  ('tags', 'character varying'),
#  ('answer_count', 'double precision'),
#  ('comment_count', 'integer'),
#  ('favourite_count', 'double precision'),
#  ('content_licensed', 'character varying'),
#  ('owner_user_id', 'integer'),
#  ('closed_date', 'character varying'),
#  ('parent_id', 'double precision'),
#  ('last_editor_display_name', 'character varying'),
#  ('community_owned_date', 'character varying')]

# %%
# %%sql
# SELECT
#    column_name,
#    data_type
# FROM
#    information_schema.columns
# WHERE
#    table_name = 'posts' AND column_name IN ('post_id', 'view_count');
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 2 rows affected.
# [('post_id', 'integer'), ('view_count', 'integer')]

# %%
# %%sql
# CREATE VIEW view_count_category_view AS
# SELECT
#  CASE
#   WHEN view_count < 10 THEN 1
#   WHEN view_count < 100 THEN 2
#   WHEN view_count < 1000 THEN 3
#   WHEN view_count < 10000 THEN 4
#   WHEN view_count < 100000 THEN 5
#   ELSE 6
#  END as view_count_category_index,
#  CASE
#   WHEN view_count < 10 THEN '0-10'
#   WHEN view_count < 100 THEN '10-100'
#   WHEN view_count < 1000 THEN '100-1000'
#   WHEN view_count < 10000 THEN '1000-10000'
#   WHEN view_count < 100000 THEN '10000-100000'
#   ELSE '100000+'
#  END as view_count_category,
#  COUNT(*)
# FROM
#  posts
# GROUP BY view_count_category, view_count_category_index
# ORDER BY view_count_category_index ASC;
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# Done.
# []

# %%
# %%sql
# SELECT * FROM view_count_category_view
# Out:
#  * postgresql://sanil:***@localhost/raspberrypidata
# 6 rows affected.
# [(1, '0-10', 1742800),
#  (2, '10-100', 49770),
#  (3, '100-1000', 265791),
#  (4, '1000-10000', 189690),
#  (5, '10000-100000', 42270),
#  (6, '100000+', 2210)]
